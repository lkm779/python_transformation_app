# %%
! pip install pandas
! pip install petl
! pip install openpyxl
! pip install global
# Out:
# zsh:1: command not found: pip
# zsh:1: command not found: pip
# zsh:1: command not found: pip
# zsh:1: command not found: pip

# %%
import pandas as pd
import petl as etl
import glob, os, json

# %%
#check CSV dfs
#product_data =  etl.fromcsv('product_data/2010-2020_Bassetlaw_outlet.csv')
#product_data.look()

# %%
#check json dfs
#json_table = etl.fromjson('json_table/2010-2020_Ceredigion_store.json')
#json_table.look()

# %%
#concatenate all CSV files 
path= "original_product_data/"

all_files = glob.glob(os.path.join(path, "*.csv"))
all_df = []
for f in all_files:
    print ("...")
    df = pd.read_csv(f, sep=',')
    #2010-2020_Bassetlaw_outlet.csv
    file_name= " ".join(f.split('/')[-1].split("_")[1:]).replace(".csv", "").strip()
    df['branch'] = file_name
    all_df.append(df)
    
        
merged_df = pd.concat(all_df, ignore_index=True, sort=True)
merged_df
# Out:
# ...
# ...
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
#           amount_in_gbp             branch category   day  hour  \
# 0                232.96     Lincoln branch      NaN  23.0   0.0
# 1                 10.56     Lincoln branch      NaN  23.0   0.0
# 2               3456.00     Lincoln branch      NaN  23.0   0.0
# 3              10291.20     Lincoln branch      NaN  23.0   0.0
# 4                505.60     Lincoln branch      NaN  23.0   0.0
# ...                 ...                ...      ...   ...   ...
# 42181901          36.50  Flintshire branch      NaN  14.0  23.0
# 42181902         306.00  Flintshire branch      NaN  14.0  23.0
# 42181903      233800.00  Flintshire branch      NaN  14.0  23.0
# 42181904          89.00  Flintshire branch      NaN  14.0  23.0
# 42181905         231.00  Flintshire branch      NaN  14.0  23.0
#
#                            item manufactuter  month  price product quantity  \
# 0              sea bass fillets          NaN    1.0    NaN     NaN      104
# 1         British carrots loose          NaN    1.0    NaN     NaN       33
# 2                  god of war 2          NaN    1.0    NaN     NaN      216
# 3                    silk scarf          NaN    1.0    NaN     NaN       96
# 4             large king prawns          NaN    1.0    NaN     NaN      158
# ...                         ...          ...    ...    ...     ...      ...
# 42181901                    NaN          NaN   12.0    NaN     NaN      NaN
# 42181902                    NaN          NaN   12.0    NaN     NaN      NaN
# 42181903                    NaN          NaN   12.0    NaN     NaN      NaN
# 42181904                    NaN          NaN   12.0    NaN     NaN      NaN
# 42181905                    NaN          NaN   12.0    NaN     NaN      NaN
#
#          quantity_purchased                     sku total_quantity  \
# 0                       NaN                     NaN            NaN
# 1                       NaN                     NaN            NaN
# 2                       NaN                     NaN            NaN
# 3                       NaN                     NaN            NaN
# 4                       NaN                     NaN            NaN
# ...                     ...                     ...            ...
# 42181901                 73         pain au raisins            NaN
# 42181902                102    diced chicken breast            NaN
# 42181903                167       hp dv 3000 laptop            NaN
# 42181904                 89  Slightly salted butter            NaN
# 42181905                231    organic soured cream            NaN
#
#          total_quantity_purchased    year
# 0                             NaN  2010.0
# 1                             NaN  2010.0
# 2                             NaN  2010.0
# 3                             NaN  2010.0
# 4                             NaN  2010.0
# ...                           ...     ...
# 42181901                      NaN  2020.0
# 42181902                      NaN  2020.0
# 42181903                      NaN  2020.0
# 42181904                      NaN  2020.0
# 42181905                      NaN  2020.0
#
# [42181906 rows x 16 columns]

# %%
merged_df.to_csv("csv_product_data.csv")

# %%
import glob, os, json

path = 'json_files_dir.csv/'

file_list = glob.glob(os.path.join(path, "*.json"))
#print(file_list)

dfjson = []
for file in file_list:
    
    print("...")
    json_data = pd.read_json(file)
    file_name= " ".join(file.split('/')[-1].split("_")[1:]).replace(".json", "").strip()
    json_data['branch'] = file_name 
    
    #print(file)


    dfjson.append(json_data)
    merge_dfjson = pd.concat(dfjson, ignore_index=True, sort=True)
(merge_dfjson)
# Out:
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
#           amount_in_gbp                  branch  day  hour  \
# 0              212.1340  Bedford Borough branch   28     0
# 1              323.2768  Bedford Borough branch   28     0
# 2             3148.8000  Bedford Borough branch   28     0
# 3               68.0600  Bedford Borough branch   28     0
# 4            15379.1000  Bedford Borough branch   28     0
# ...                 ...                     ...  ...   ...
# 45560532       744.0000    Richmondshire outlet   23    23
# 45560533       137.7600    Richmondshire outlet   23    23
# 45560534       241.4000    Richmondshire outlet   23    23
# 45560535        40.0000    Richmondshire outlet   23    23
# 45560536     56700.0000    Richmondshire outlet   23    23
#
#                                     item  month                 product  \
# 0                          Organic Kefir      1                     NaN
# 1         british bramley cooking apples      1                     NaN
# 2                           god of war 2      1                     NaN
# 3                        vanilla yoghurt      1                     NaN
# 4                        gameboy advance      1                     NaN
# ...                                  ...    ...                     ...
# 45560532                             NaN     12        wellington boots
# 45560533                             NaN     12  british parsnips loose
# 45560534                             NaN     12      fresh whole turkey
# 45560535                             NaN     12      millionaire square
# 45560536                             NaN     12    dyson vacuum cleaner
#
#          quantity quantity_purchased  sku total_quantity  \
# 0             NaN                199  NaN            NaN
# 1             NaN                224  NaN            NaN
# 2             NaN                192  NaN            NaN
# 3             NaN                 83  NaN            NaN
# 4             NaN                121  NaN            NaN
# ...           ...                ...  ...            ...
# 45560532      NaN                NaN  NaN            NaN
# 45560533      NaN                NaN  NaN            NaN
# 45560534      NaN                NaN  NaN            NaN
# 45560535      NaN                NaN  NaN            NaN
# 45560536      NaN                NaN  NaN            NaN
#
#          total_quantity_purchased  year
# 0                             NaN  2011
# 1                             NaN  2011
# 2                             NaN  2011
# 3                             NaN  2011
# 4                             NaN  2011
# ...                           ...   ...
# 45560532                       31  2020
# 45560533                      164  2020
# 45560534                      142  2020
# 45560535                       20  2020
# 45560536                       81  2020
#
# [45560537 rows x 13 columns]

# %%
#export to csv single file
merge_dfjson.to_csv("json_product_data.csv")

# %%
#inspect excel branch expenses data and create table
expenses_db_table_excel=etl.fromxlsx('xlsx/branch_expenses.xlsx')
expenses_db_table_excel.look()
# Out:
# +--------+-------+-------------------+----------------+----------------------+----------------+------------------+---------------+---------------+------------+
# | year   | month | region            | county         | branch_name          | established_on | operational_cost | staff_bonuses | misc_expenses | waste_cost |
# +========+=======+===================+================+======================+================+==================+===============+===============+============+
# | 2012.0 |   1.0 | 'East of England' | 'Bedfordshire' | 'Bedfordshire store' |         2012.0 |           2785.0 |         232.0 |        7793.0 |     4729.0 |
# +--------+-------+-------------------+----------------+----------------------+----------------+------------------+---------------+---------------+------------+
# | 2012.0 |   2.0 | 'East of England' | 'Bedfordshire' | 'Bedfordshire store' |         2012.0 |           2058.0 |         260.0 |        3559.0 |     3539.0 |
# +--------+-------+-------------------+----------------+----------------------+----------------+------------------+---------------+---------------+------------+
# | 2012.0 |   3.0 | 'East of England' | 'Bedfordshire' | 'Bedfordshire store' |         2012.0 |           2222.0 |         319.0 |        7320.0 |     2809.0 |
# +--------+-------+-------------------+----------------+----------------------+----------------+------------------+---------------+---------------+------------+
# | 2012.0 |   4.0 | 'East of England' | 'Bedfordshire' | 'Bedfordshire store' |         2012.0 |           2324.0 |         271.0 |        3352.0 |     3704.0 |
# +--------+-------+-------------------+----------------+----------------------+----------------+------------------+---------------+---------------+------------+
# | 2012.0 |   5.0 | 'East of England' | 'Bedfordshire' | 'Bedfordshire store' |         2012.0 |           2489.0 |         263.0 |        5834.0 |     3872.0 |
# +--------+-------+-------------------+----------------+----------------------+----------------+------------------+---------------+---------------+------------+
# ...

# %%
#inspect excel branch list data and create table
blist_db_table_excel=etl.fromxlsx('xlsx/branch_list.xlsx')
blist_db_table_excel.look()
# Out:
# +-------------------+-----------------------+------------------------------+----------------+
# | region            | county                | branch_name                  | established_on |
# +===================+=======================+==============================+================+
# | 'East of England' | 'Bedfordshire'        | 'Bedfordshire store'         |         2012.0 |
# +-------------------+-----------------------+------------------------------+----------------+
# | 'East of England' | 'East Cambridgeshire' | 'East Cambridgeshire outlet' |         2010.0 |
# +-------------------+-----------------------+------------------------------+----------------+
# | 'West Midlands'   | 'Warwickshire'        | 'Warwickshire branch'        |         2010.0 |
# +-------------------+-----------------------+------------------------------+----------------+
# | 'East Midlands'   | 'Lincolnshire'        | 'Lincolnshire store'         |         2012.0 |
# +-------------------+-----------------------+------------------------------+----------------+
# | 'London'          | 'Islington'           | 'Islington branch'           |         2011.0 |
# +-------------------+-----------------------+------------------------------+----------------+
# ...

# %%
#inspect product list data and create table
product_list = etl.fromcsv('original_product_data/products_list.csv')
product_list.look()
# Out:
# +---------------------------------+--------------+-----------------------+--------+
# | product                         | manufactuter | category              | price  |
# +=================================+==============+=======================+========+
# | 'Fairtrade Bananas Loose'       | 'sainsburys' | 'fruits & vegetable'  | '0.79' |
# +---------------------------------+--------------+-----------------------+--------+
# | 'British carrots loose'         | 'sainsburys' | 'fruits & vegetables' | '0.4'  |
# +---------------------------------+--------------+-----------------------+--------+
# | 'Onions Loose'                  | 'sainsburys' | 'fruits & vegetables' | '0.85' |
# +---------------------------------+--------------+-----------------------+--------+
# | 'British baking potatoes loose' | 'sainsburys' | 'fruits & vegetables' | '0.83' |
# +---------------------------------+--------------+-----------------------+--------+
# | 'Red pepper'                    | 'sainsburys' | 'fruits & vegetables' | '0.42' |
# +---------------------------------+--------------+-----------------------+--------+
# ...

# %%
#merge two excel tables
table_c_excel = etl.join(blist_db_table_excel, expenses_db_table_excel)
table_c_excel.look()
# Out:
# +-----------------+-------------+--------------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# | region          | county      | branch_name        | established_on | year   | month | operational_cost | staff_bonuses | misc_expenses | waste_cost |
# +=================+=============+====================+================+========+=======+==================+===============+===============+============+
# | 'East Midlands' | 'Bassetlaw' | 'Bassetlaw outlet' |         2010.0 | 2010.0 |   1.0 |           2838.0 |         296.0 |        9455.0 |     6366.0 |
# +-----------------+-------------+--------------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# | 'East Midlands' | 'Bassetlaw' | 'Bassetlaw outlet' |         2010.0 | 2010.0 |   2.0 |           2280.0 |         313.0 |        4346.0 |     6003.0 |
# +-----------------+-------------+--------------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# | 'East Midlands' | 'Bassetlaw' | 'Bassetlaw outlet' |         2010.0 | 2010.0 |   3.0 |           2327.0 |         312.0 |        8107.0 |     5990.0 |
# +-----------------+-------------+--------------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# | 'East Midlands' | 'Bassetlaw' | 'Bassetlaw outlet' |         2010.0 | 2010.0 |   4.0 |           3028.0 |         269.0 |        8353.0 |     2354.0 |
# +-----------------+-------------+--------------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# | 'East Midlands' | 'Bassetlaw' | 'Bassetlaw outlet' |         2010.0 | 2010.0 |   5.0 |           3226.0 |         296.0 |        7532.0 |     6455.0 |
# +-----------------+-------------+--------------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# ...

# %%
#rename column in excel table in accordance to the previous tables
table_d_excel = etl.rename(table_c_excel, 'branch_name','branch')
table_d_excel.look()
# Out:
# +-----------------+-------------+--------------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# | region          | county      | branch             | established_on | year   | month | operational_cost | staff_bonuses | misc_expenses | waste_cost |
# +=================+=============+====================+================+========+=======+==================+===============+===============+============+
# | 'East Midlands' | 'Bassetlaw' | 'Bassetlaw outlet' |         2010.0 | 2010.0 |   1.0 |           2838.0 |         296.0 |        9455.0 |     6366.0 |
# +-----------------+-------------+--------------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# | 'East Midlands' | 'Bassetlaw' | 'Bassetlaw outlet' |         2010.0 | 2010.0 |   2.0 |           2280.0 |         313.0 |        4346.0 |     6003.0 |
# +-----------------+-------------+--------------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# | 'East Midlands' | 'Bassetlaw' | 'Bassetlaw outlet' |         2010.0 | 2010.0 |   3.0 |           2327.0 |         312.0 |        8107.0 |     5990.0 |
# +-----------------+-------------+--------------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# | 'East Midlands' | 'Bassetlaw' | 'Bassetlaw outlet' |         2010.0 | 2010.0 |   4.0 |           3028.0 |         269.0 |        8353.0 |     2354.0 |
# +-----------------+-------------+--------------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# | 'East Midlands' | 'Bassetlaw' | 'Bassetlaw outlet' |         2010.0 | 2010.0 |   5.0 |           3226.0 |         296.0 |        7532.0 |     6455.0 |
# +-----------------+-------------+--------------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# ...

# %%
#already edited csv file data to etl table for manipulation
db_table_csv=etl.fromcsv('manipulated_data/csv_product_data.csv')
db_table_csv.look()
# Out:
# +-----+--------+-------+-----+------+-------------------------+--------------------+----------------------+---------------------+
# |     | year   | month | day | hour | sku                     | quantity_purchased | amount_in_gbp        | branch              |
# +=====+========+=======+=====+======+=========================+====================+======================+=====================+
# | '0' | '2010' | '1'   | '5' | '0'  | 'god of war 2'          | '216'              | '3456.0'             | 'Flintshire branch' |
# +-----+--------+-------+-----+------+-------------------------+--------------------+----------------------+---------------------+
# | '1' | '2010' | '1'   | '5' | '0'  | 'Onions Loose'          | '207'              | '140.76000000000002' | 'Flintshire branch' |
# +-----+--------+-------+-----+------+-------------------------+--------------------+----------------------+---------------------+
# | '2' | '2010' | '1'   | '5' | '0'  | 'Oats Milk'             | '179'              | '272.08'             | 'Flintshire branch' |
# +-----+--------+-------+-----+------+-------------------------+--------------------+----------------------+---------------------+
# | '3' | '2010' | '1'   | '5' | '0'  | 'dyson washing machine' | '40'               | '9600.0'             | 'Flintshire branch' |
# +-----+--------+-------+-----+------+-------------------------+--------------------+----------------------+---------------------+
# | '4' | '2010' | '1'   | '5' | '0'  | 'unsalted butter'       | '9'                | '7.2'                | 'Flintshire branch' |
# +-----+--------+-------+-----+------+-------------------------+--------------------+----------------------+---------------------+
# ...

# %%
#already edited json file data to etl table for manipulation
db_table_json=etl.fromcsv('manipulated_data/json_product_data.csv')
db_table_json.look()
# Out:
# +-----+--------+-------+------+------+------------------------------+--------------------------+---------------+---------------------------------------+
# |     | year   | month | day  | hour | product                      | total_quantity_purchased | amount_in_gbp | branch                                |
# +=====+========+=======+======+======+==============================+==========================+===============+=======================================+
# | '0' | '2010' | '1'   | '24' | '0'  | 'apple macbook air mid 2009' | '5'                      | '7600.0'      | '2010-2020_Richmondshire_outlet.json' |
# +-----+--------+-------+------+------+------------------------------+--------------------------+---------------+---------------------------------------+
# | '1' | '2010' | '1'   | '24' | '0'  | 'scottish salmon'            | '85'                     | '272.0'       | '2010-2020_Richmondshire_outlet.json' |
# +-----+--------+-------+------+------+------------------------------+--------------------------+---------------+---------------------------------------+
# | '2' | '2010' | '1'   | '24' | '0'  | 'mature cheddar cheese'      | '21'                     | '40.32'       | '2010-2020_Richmondshire_outlet.json' |
# +-----+--------+-------+------+------+------------------------------+--------------------------+---------------+---------------------------------------+
# | '3' | '2010' | '1'   | '24' | '0'  | 'Sweet potatoes loose'       | '37'                     | '32.56'       | '2010-2020_Richmondshire_outlet.json' |
# +-----+--------+-------+------+------+------------------------------+--------------------------+---------------+---------------------------------------+
# | '4' | '2010' | '1'   | '24' | '0'  | 'pink blazers'               | '207'                    | '8280.0'      | '2010-2020_Richmondshire_outlet.json' |
# +-----+--------+-------+------+------+------------------------------+--------------------------+---------------+---------------------------------------+
# ...

# %%
#join json table and excel table
final_table_json=etl.lookupjoin(db_table_json, table_d_excel, key='branch')
final_table_json.look()
# Out:
# +-----+--------+-------+------+------+------------------------------+--------------------------+---------------+---------------------------------------+--------+--------+----------------+------+-------+------------------+---------------+---------------+------------+
# |     | year   | month | day  | hour | product                      | total_quantity_purchased | amount_in_gbp | branch                                | region | county | established_on | year | month | operational_cost | staff_bonuses | misc_expenses | waste_cost |
# +=====+========+=======+======+======+==============================+==========================+===============+=======================================+========+========+================+======+=======+==================+===============+===============+============+
# | '0' | '2010' | '1'   | '24' | '0'  | 'apple macbook air mid 2009' | '5'                      | '7600.0'      | '2010-2020_Richmondshire_outlet.json' | None   | None   | None           | None | None  | None             | None          | None          | None       |
# +-----+--------+-------+------+------+------------------------------+--------------------------+---------------+---------------------------------------+--------+--------+----------------+------+-------+------------------+---------------+---------------+------------+
# | '1' | '2010' | '1'   | '24' | '0'  | 'scottish salmon'            | '85'                     | '272.0'       | '2010-2020_Richmondshire_outlet.json' | None   | None   | None           | None | None  | None             | None          | None          | None       |
# +-----+--------+-------+------+------+------------------------------+--------------------------+---------------+---------------------------------------+--------+--------+----------------+------+-------+------------------+---------------+---------------+------------+
# | '2' | '2010' | '1'   | '24' | '0'  | 'mature cheddar cheese'      | '21'                     | '40.32'       | '2010-2020_Richmondshire_outlet.json' | None   | None   | None           | None | None  | None             | None          | None          | None       |
# +-----+--------+-------+------+------+------------------------------+--------------------------+---------------+---------------------------------------+--------+--------+----------------+------+-------+------------------+---------------+---------------+------------+
# | '3' | '2010' | '1'   | '24' | '0'  | 'Sweet potatoes loose'       | '37'                     | '32.56'       | '2010-2020_Richmondshire_outlet.json' | None   | None   | None           | None | None  | None             | None          | None          | None       |
# +-----+--------+-------+------+------+------------------------------+--------------------------+---------------+---------------------------------------+--------+--------+----------------+------+-------+------------------+---------------+---------------+------------+
# | '4' | '2010' | '1'   | '24' | '0'  | 'pink blazers'               | '207'                    | '8280.0'      | '2010-2020_Richmondshire_outlet.json' | None   | None   | None           | None | None  | None             | None          | None          | None       |
# +-----+--------+-------+------+------+------------------------------+--------------------------+---------------+---------------------------------------+--------+--------+----------------+------+-------+------------------+---------------+---------------+------------+
# ...

# %%
#join csv table and excel table
final_table_csv=etl.lookupjoin(db_table_csv, table_d_excel, key='branch')
final_table_csv.look()
# Out:
# +-----+--------+-------+-----+------+-------------------------+--------------------+----------------------+---------------------+---------+--------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# |     | year   | month | day | hour | sku                     | quantity_purchased | amount_in_gbp        | branch              | region  | county       | established_on | year   | month | operational_cost | staff_bonuses | misc_expenses | waste_cost |
# +=====+========+=======+=====+======+=========================+====================+======================+=====================+=========+==============+================+========+=======+==================+===============+===============+============+
# | '0' | '2010' | '1'   | '5' | '0'  | 'god of war 2'          | '216'              | '3456.0'             | 'Flintshire branch' | 'Wales' | 'Flintshire' |         2010.0 | 2010.0 |   1.0 |           2864.0 |         306.0 |        7853.0 |     6479.0 |
# +-----+--------+-------+-----+------+-------------------------+--------------------+----------------------+---------------------+---------+--------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# | '1' | '2010' | '1'   | '5' | '0'  | 'Onions Loose'          | '207'              | '140.76000000000002' | 'Flintshire branch' | 'Wales' | 'Flintshire' |         2010.0 | 2010.0 |   1.0 |           2864.0 |         306.0 |        7853.0 |     6479.0 |
# +-----+--------+-------+-----+------+-------------------------+--------------------+----------------------+---------------------+---------+--------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# | '2' | '2010' | '1'   | '5' | '0'  | 'Oats Milk'             | '179'              | '272.08'             | 'Flintshire branch' | 'Wales' | 'Flintshire' |         2010.0 | 2010.0 |   1.0 |           2864.0 |         306.0 |        7853.0 |     6479.0 |
# +-----+--------+-------+-----+------+-------------------------+--------------------+----------------------+---------------------+---------+--------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# | '3' | '2010' | '1'   | '5' | '0'  | 'dyson washing machine' | '40'               | '9600.0'             | 'Flintshire branch' | 'Wales' | 'Flintshire' |         2010.0 | 2010.0 |   1.0 |           2864.0 |         306.0 |        7853.0 |     6479.0 |
# +-----+--------+-------+-----+------+-------------------------+--------------------+----------------------+---------------------+---------+--------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# | '4' | '2010' | '1'   | '5' | '0'  | 'unsalted butter'       | '9'                | '7.2'                | 'Flintshire branch' | 'Wales' | 'Flintshire' |         2010.0 | 2010.0 |   1.0 |           2864.0 |         306.0 |        7853.0 |     6479.0 |
# +-----+--------+-------+-----+------+-------------------------+--------------------+----------------------+---------------------+---------+--------------+----------------+--------+-------+------------------+---------------+---------------+------------+
# ...

# %%
#concatenation of json and csv table
final_unified_table= etl.cat(final_table_json, final_table_csv)

# %%
final_unified_table= etl.leftjoin(final_unified_table, product_list, key='product')
final_unified_table.look()
# Out:
# +-----+--------+-------+-----+------+---------+--------------------------+----------------------+---------------------+---------+--------------+----------------+--------+-------+------------------+---------------+---------------+------------+-------------------------+--------------------+--------------+----------+-------+
# |     | year   | month | day | hour | product | total_quantity_purchased | amount_in_gbp        | branch              | region  | county       | established_on | year   | month | operational_cost | staff_bonuses | misc_expenses | waste_cost | sku                     | quantity_purchased | manufactuter | category | price |
# +=====+========+=======+=====+======+=========+==========================+======================+=====================+=========+==============+================+========+=======+==================+===============+===============+============+=========================+====================+==============+==========+=======+
# | '0' | '2010' | '1'   | '5' | '0'  | None    | None                     | '3456.0'             | 'Flintshire branch' | 'Wales' | 'Flintshire' |         2010.0 | '2010' | '1'   |           2864.0 |         306.0 |        7853.0 |     6479.0 | 'god of war 2'          | '216'              | None         | None     | None  |
# +-----+--------+-------+-----+------+---------+--------------------------+----------------------+---------------------+---------+--------------+----------------+--------+-------+------------------+---------------+---------------+------------+-------------------------+--------------------+--------------+----------+-------+
# | '1' | '2010' | '1'   | '5' | '0'  | None    | None                     | '140.76000000000002' | 'Flintshire branch' | 'Wales' | 'Flintshire' |         2010.0 | '2010' | '1'   |           2864.0 |         306.0 |        7853.0 |     6479.0 | 'Onions Loose'          | '207'              | None         | None     | None  |
# +-----+--------+-------+-----+------+---------+--------------------------+----------------------+---------------------+---------+--------------+----------------+--------+-------+------------------+---------------+---------------+------------+-------------------------+--------------------+--------------+----------+-------+
# | '2' | '2010' | '1'   | '5' | '0'  | None    | None                     | '272.08'             | 'Flintshire branch' | 'Wales' | 'Flintshire' |         2010.0 | '2010' | '1'   |           2864.0 |         306.0 |        7853.0 |     6479.0 | 'Oats Milk'             | '179'              | None         | None     | None  |
# +-----+--------+-------+-----+------+---------+--------------------------+----------------------+---------------------+---------+--------------+----------------+--------+-------+------------------+---------------+---------------+------------+-------------------------+--------------------+--------------+----------+-------+
# | '3' | '2010' | '1'   | '5' | '0'  | None    | None                     | '9600.0'             | 'Flintshire branch' | 'Wales' | 'Flintshire' |         2010.0 | '2010' | '1'   |           2864.0 |         306.0 |        7853.0 |     6479.0 | 'dyson washing machine' | '40'               | None         | None     | None  |
# +-----+--------+-------+-----+------+---------+--------------------------+----------------------+---------------------+---------+--------------+----------------+--------+-------+------------------+---------------+---------------+------------+-------------------------+--------------------+--------------+----------+-------+
# | '4' | '2010' | '1'   | '5' | '0'  | None    | None                     | '7.2'                | 'Flintshire branch' | 'Wales' | 'Flintshire' |         2010.0 | '2010' | '1'   |           2864.0 |         306.0 |        7853.0 |     6479.0 | 'unsalted butter'       | '9'                | None         | None     | None  |
# +-----+--------+-------+-----+------+---------+--------------------------+----------------------+---------------------+---------+--------------+----------------+--------+-------+------------------+---------------+---------------+------------+-------------------------+--------------------+--------------+----------+-------+
# ...

# %%
#cleaning of column fields
final_transformed_data_df= etl.addfield(final_unified_table, 'q', lambda cell:['total_quantity_purchased']+cell['quantity_purchased']+cell['total_quantity']+cell['quantity'])

# %%
#adding fields to goods column
final_transformed_data_df=etl.addfield(final_transformed_data_df, 'goods', lambda cell:['product']+cell['item']+cell['sku'])

# %%
#table cleaning of columns
table_clean= etl.cutout(final_transformed_data_df, 'total_quantity_purchased', 'quantity_purchased', 'product', 'sku' )

# %%
#Check before final export
table_clean.look()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/util/vis.py in __repr__(self)
#     102
#     103         # determine if table overflows limit
# --> 104         table, overflow = _vis_overflow(self.table, self.limit)
#     105
#     106         # construct output
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/util/vis.py in _vis_overflow(table, limit)
#     526     if limit:
#     527         # try reading one more than the limit, to see if there are more rows
# --> 528         table = list(islice(table, 0, limit+2))
#     529         if len(table) > limit+1:
#     530             overflow = True
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in itercutout(source, spec, missing)
#     215
#     216     # construct the transformed data
# --> 217     for row in it:
#     218         try:
#     219             yield transform(row)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in iteraddfield(source, field, value, index)
#     542         # wrap rows as records if using calculated value
#     543         it = (Record(row, flds) for row in it)
# --> 544         for row in it:
#     545             outrow = list(row)
#     546             v = value(row)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in <genexpr>(.0)
#     541     if callable(value):
#     542         # wrap rows as records if using calculated value
# --> 543         it = (Record(row, flds) for row in it)
#     544         for row in it:
#     545             outrow = list(row)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in iterstack(sources, missing, trim, pad)
#     457     yield tuple(hdr)
#     458     for it in its:
# --> 459         for row in it:
#     460             outrow = tuple(row)
#     461             if trim:
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in iteraddfield(source, field, value, index)
#     542         # wrap rows as records if using calculated value
#     543         it = (Record(row, flds) for row in it)
# --> 544         for row in it:
#     545             outrow = list(row)
#     546             v = value(row)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in <genexpr>(.0)
#     541     if callable(value):
#     542         # wrap rows as records if using calculated value
# --> 543         it = (Record(row, flds) for row in it)
#     544         for row in it:
#     545             outrow = list(row)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in iterstack(sources, missing, trim, pad)
#     457     yield tuple(hdr)
#     458     for it in its:
# --> 459         for row in it:
#     460             outrow = tuple(row)
#     461             if trim:
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in iteraddfield(source, field, value, index)
#     544         for row in it:
#     545             outrow = list(row)
# --> 546             v = value(row)
#     547             outrow.insert(index, v)
#     548             yield tuple(outrow)
#
# /var/folders/md/qyvwrp_j33sc6jrryt9yr7gr0000gn/T/ipykernel_31092/1965183607.py in <lambda>(cell)
#       1 #cleaning of column fields
# ----> 2 final_transformed_data_df= etl.addfield(final_unified_table, 'q', lambda cell:['total_quantity_purchased']+cell['quantity_purchased']+cell['total_quantity']+cell['quantity'])
#
# TypeError: can only concatenate list (not "str") to list

# %%
#export etl table to CSV for filtering and dash 
etl.tocsv(table_clean, 'final_cleaned_df.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/md/qyvwrp_j33sc6jrryt9yr7gr0000gn/T/ipykernel_31092/557647032.py in <module>
# ----> 1 etl.tocsv(table_clean, 'final_cleaned_df.csv')
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/io/csv.py in tocsv(table, source, encoding, errors, write_header, **csvargs)
#     106     source = write_source_from_arg(source)
#     107     csvargs.setdefault('dialect', 'excel')
# --> 108     tocsv_impl(table, source=source, encoding=encoding, errors=errors,
#     109                write_header=write_header, **csvargs)
#     110
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/io/csv_py3.py in tocsv_impl(table, source, **kwargs)
#      42
#      43 def tocsv_impl(table, source, **kwargs):
# ---> 44     _writecsv(table, source=source, mode='wb', **kwargs)
#      45
#      46
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/io/csv_py3.py in _writecsv(table, source, mode, write_header, encoding, errors, **csvargs)
#      57         try:
#      58             writer = csv.writer(csvfile, **csvargs)
# ---> 59             for row in rows:
#      60                 writer.writerow(row)
#      61             csvfile.flush()
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in itercutout(source, spec, missing)
#     215
#     216     # construct the transformed data
# --> 217     for row in it:
#     218         try:
#     219             yield transform(row)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in iteraddfield(source, field, value, index)
#     542         # wrap rows as records if using calculated value
#     543         it = (Record(row, flds) for row in it)
# --> 544         for row in it:
#     545             outrow = list(row)
#     546             v = value(row)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in <genexpr>(.0)
#     541     if callable(value):
#     542         # wrap rows as records if using calculated value
# --> 543         it = (Record(row, flds) for row in it)
#     544         for row in it:
#     545             outrow = list(row)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in iterstack(sources, missing, trim, pad)
#     457     yield tuple(hdr)
#     458     for it in its:
# --> 459         for row in it:
#     460             outrow = tuple(row)
#     461             if trim:
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in iteraddfield(source, field, value, index)
#     542         # wrap rows as records if using calculated value
#     543         it = (Record(row, flds) for row in it)
# --> 544         for row in it:
#     545             outrow = list(row)
#     546             v = value(row)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in <genexpr>(.0)
#     541     if callable(value):
#     542         # wrap rows as records if using calculated value
# --> 543         it = (Record(row, flds) for row in it)
#     544         for row in it:
#     545             outrow = list(row)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in iterstack(sources, missing, trim, pad)
#     457     yield tuple(hdr)
#     458     for it in its:
# --> 459         for row in it:
#     460             outrow = tuple(row)
#     461             if trim:
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/petl/transform/basics.py in iteraddfield(source, field, value, index)
#     544         for row in it:
#     545             outrow = list(row)
# --> 546             v = value(row)
#     547             outrow.insert(index, v)
#     548             yield tuple(outrow)
#
# /var/folders/md/qyvwrp_j33sc6jrryt9yr7gr0000gn/T/ipykernel_31092/1965183607.py in <lambda>(cell)
#       1 #cleaning of column fields
# ----> 2 final_transformed_data_df= etl.addfield(final_unified_table, 'q', lambda cell:['total_quantity_purchased']+cell['quantity_purchased']+cell['total_quantity']+cell['quantity'])
#
# TypeError: can only concatenate list (not "str") to list
